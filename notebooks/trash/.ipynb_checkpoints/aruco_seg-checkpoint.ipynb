# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
bgr = cv2.imread('sat1.png')
img = cv2.imread('sat1.png',0)
plt.imshow(img,cmap='gray')

# %%
# img = cv2.medianBlur(img,5)
plt.figure(figsize=(15,15))
thresh1 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,3,7)
plt.subplot(3,3,1), plt.imshow(thresh1)
thresh2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,13,7)
plt.subplot(3,3,2), plt.imshow(thresh2)
thresh3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,23,7)
plt.subplot(3,3,3), plt.imshow(thresh3)
edged_thresh3 = cv2.Canny(thresh3,50,100)
plt.subplot(3,3,4), plt.imshow(edged_thresh3)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f573759dc10>,
#  <matplotlib.image.AxesImage at 0x7f57375506d0>)

# %%
plt.hist(img.flatten())
# Out:
# (array([4.2910e+03, 1.7439e+04, 3.1120e+03, 2.5700e+02, 3.6000e+02,
#         5.5700e+02, 1.2310e+03, 3.0000e+01, 1.6000e+01, 7.0000e+00]),
#  array([  0. ,  15.9,  31.8,  47.7,  63.6,  79.5,  95.4, 111.3, 127.2,
#         143.1, 159. ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(15,15))
edged = cv2.Canny(img,25,50)
plt.subplot(1,3,1), plt.imshow(edged)
edged = cv2.Canny(img,50,100)
plt.subplot(1,3,2), plt.imshow(edged)
edged = cv2.Canny(img,100,200)
plt.subplot(1,3,3), plt.imshow(edged)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f57377c0760>,
#  <matplotlib.image.AxesImage at 0x7f57377f0220>)

# %%
cnts, hier = cv2.findContours(thresh3, cv2.RETR_EXTERNAL,
                        cv2.CHAIN_APPROX_SIMPLE)

# %%
cnt_img = cv2.drawContours(bgr,cnts,-1,(0,255,0),1)
plt.imshow(cnt_img)

# %%
img = cv2.imread('sat1.png',0)
edged = cv2.Canny(img,50,100)
lines = cv2.HoughLines(edged,1,np.pi/180, 200) 
  
# The below for loop runs till r and theta values  
# are in the range of the 2d array 
for r,theta in lines[0]: 
      
    # Stores the value of cos(theta) in a 
    a = np.cos(theta) 
  
    # Stores the value of sin(theta) in b 
    b = np.sin(theta) 
      
    # x0 stores the value rcos(theta) 
    x0 = a*r 
      
    # y0 stores the value rsin(theta) 
    y0 = b*r 
      
    # x1 stores the rounded off value of (rcos(theta)-1000sin(theta)) 
    x1 = int(x0 + 1000*(-b)) 
      
    # y1 stores the rounded off value of (rsin(theta)+1000cos(theta)) 
    y1 = int(y0 + 1000*(a)) 
  
    # x2 stores the rounded off value of (rcos(theta)+1000sin(theta)) 
    x2 = int(x0 - 1000*(-b)) 
      
    # y2 stores the rounded off value of (rsin(theta)-1000cos(theta)) 
    y2 = int(y0 - 1000*(a)) 
      
    # cv2.line draws a line in img from the point(x1,y1) to (x2,y2). 
    # (0,0,255) denotes the colour of the line to be  
    #drawn. In this case, it is red.  
    img = cv2.line(img,(x1,y1), (x2,y2), (0,0,255),2) 

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-5090e99dc4ba> in <module>
#       5 # The below for loop runs till r and theta values
#       6 # are in the range of the 2d array
# ----> 7 for r,theta in lines[0]:
#       8
#       9     # Stores the value of cos(theta) in a
#
# TypeError: 'NoneType' object is not subscriptable
